# %%
import numpy 
import matplotlib.pyplot as plt
import cv2 as cv

# %%
image = cv.imread("image/12.jpg")
plt.imshow(image)

# %%
 x=25
y= 65
print(x+ y)
# Out:
# 90

# %%
x =  [4 , 5 , 6 , 3 , 2 , 1 , 8 ]
y =  [ 1 , 6 , 5 , 4 , 8 , 9 , 3 ]
plt.plot(x,y)
plt.xlabel("days")
# Out:
# Text(0.5, 0, 'days')
